# %% [markdown]
# <a href="https://colab.research.google.com/github/jrleonett/fooocus/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generación de Imágenes con Fooocus
#
# Este notebook utiliza el proyecto de código abierto **Fooocus** para generar imágenes a partir de descripciones textuales. El código clona el repositorio de Fooocus, instala las dependencias necesarias, ejecuta el modelo y abre automáticamente la interfaz generada en tu navegador.
#
# **¿Para qué sirve?**
# - Generar imágenes a partir de texto.
# - Explorar modelos de IA para creación de arte y diseño.
# - Usar Fooocus en Google Colab sin necesidad de configuración local.
#
# **¿Cómo funciona?**
# 1. Clona el repositorio de Fooocus.
# 2. Instala las dependencias necesarias.
# 3. Ejecuta el modelo y abre la interfaz en tu navegador.
#
# ¡Prueba la generación de imágenes con Fooocus ahora!

# %%
#@title [01] Instalar dependencias necesarias ✔

# Verificación de la GPU asignada (opcional)
# !nvidia-smi
# !/usr/local/cuda/bin/nvcc --version

# !pip install pygit2==1.15.1
# !pip install --upgrade gradio  # Actualizar Gradio a la última versión

# Cambiar al directorio de trabajo
# %cd /content

# Clonar el repositorio de Fooocus
# !git clone https://github.com/lllyasviel/Fooocus.git

# Cambiar al directorio del repositorio clonado
# %cd /content/Fooocus

# Ejecutar el script principal
output = !python entry_with_update.py --share --always-high-vram

# Buscar la URL generada en la salida del script
import re
import webbrowser

for line in output:
    # Buscar la URL en el formato "http://127.0.0.1:7865" o similar
    match = re.search(r"http://\d+\.\d+\.\d+\.\d+:\d+", line)
    if match:
        url = match.group(0)
        print(f"Abrir automáticamente: {url}")
        webbrowser.open(url)  # Abre la URL en una nueva pestaña
        break
    # Si no encuentra la URL local, buscar una URL de Gradio (https://<algo>.gradio.app)
    match_gradio = re.search(r"https://[\w\-\.]+\.gradio\.app", line)
    if match_gradio:
        url_gradio = match_gradio.group(0)
        print(f"Abrir automáticamente: {url_gradio}")
        webbrowser.open(url_gradio)  # Abre la URL de Gradio en una nueva pestaña
        break
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 17.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.16.0
#     Uninstalling pygit2-1.16.0:
#       Successfully uninstalled pygit2-1.16.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 MB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.4/320.4 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 56.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 3.2 MB/s eta 0:00:00
# ...
